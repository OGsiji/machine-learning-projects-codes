# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv('train.csv', usecols=id)
test=pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    BCT_CODBUR  CTR_MATFIS CTR_CATEGO_X  FJU_CODFJU  CTR_CESSAT  ACT_CODACT  \
# 0          49       14185            P          99           1        6101
# 1         221        6032            P          99           0        6271
# 2         181        8907            P          99           0        6102
# 3         252        5783            M          22           0        4403
# 4         234        1477            P          99           0        6312
#
#    CTR_OBLDIR  CTR_OBLACP  CTR_OBLRES  CTR_OBLFOP  ...     target  \
# 0           4           2           2           2  ...  13.575957
# 1           8           2           1           1  ...  11.692894
# 2           4           2           2           2  ...   0.000000
# 3           4           2           2           2  ...  16.237871
# 4           8           2           2           1  ...  13.399983
#
#    FAC_MNTPRI_F  FAC_MFODEC_F  FAC_MNTDCO_F  FAC_MNTTVA_F  FAC_MNTPRI_C  \
# ...

# %%
test.head()
# Out:
#    BCT_CODBUR  CTR_MATFIS CTR_CATEGO_X  FJU_CODFJU  CTR_CESSAT  ACT_CODACT  \
# 0           9       11802            P          99           0        6306
# 1         255        2713            C          99           0        4409
# 2         201         152            M          22           0        3603
# 3         302        7698            M          22           0        4203
# 4         152         544            P          99           0        6307
#
#    CTR_OBLDIR  CTR_OBLACP  CTR_OBLRES  CTR_OBLFOP  ...  RES_ANNIMP  \
# 0           8           2           2           2  ...        2015
# 1           4           2           2           2  ...        2016
# 2           4           2           2           2  ...        2016
# 3           4           2           2           2  ...        2013
# 4           4           2           2           2  ...        2013
#
#    FAC_MNTPRI_F  FAC_MFODEC_F  FAC_MNTDCO_F  FAC_MNTTVA_F  FAC_MNTPRI_C  \
# ...

# %%
train.describe()
# Out:
#          BCT_CODBUR    CTR_MATFIS    FJU_CODFJU    CTR_CESSAT    ACT_CODACT  \
# count  25053.000000  25053.000000  25053.000000  25053.000000  25053.000000
# mean     214.937453   7791.431326     59.582685      0.048697   4818.192791
# std      163.089484   4494.622188     38.541612      0.228200   1168.145804
# min        9.000000      1.000000     10.000000      0.000000   1002.000000
# 25%       92.000000   3923.000000     22.000000      0.000000   4203.000000
# 50%      182.000000   7822.000000     23.000000      0.000000   4417.000000
# 75%      254.000000  11703.000000     99.000000      0.000000   6102.000000
# max      700.000000  15603.000000     99.000000      2.000000   8999.000000
#
#          CTR_OBLDIR    CTR_OBLACP    CTR_OBLRES    CTR_OBLFOP   CTR_OBLTFP  \
# count  25053.000000  25053.000000  25053.000000  25053.000000  25053.00000
# mean       4.451483      1.960444      1.977049      1.927913      1.94827
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25053 entries, 0 to 25052
# Columns: 121 entries, BCT_CODBUR to id
# dtypes: float64(103), int64(16), object(2)
# memory usage: 23.1+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10738 entries, 0 to 10737
# Columns: 120 entries, BCT_CODBUR to id
# dtypes: float64(102), int64(16), object(2)
# memory usage: 9.8+ MB

# %%
sns.heatmap(train.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
train['target'].hist(color='darkred', bins=30, alpha=0.6)

# %%
missing_values_count = train.isnull().sum()
missing_values_count
# Out:
# BCT_CODBUR          0
# CTR_MATFIS          0
# CTR_CATEGO_X        0
# FJU_CODFJU          0
# CTR_CESSAT          0
# ACT_CODACT          0
# CTR_OBLDIR          0
# CTR_OBLACP          0
# CTR_OBLRES          0
# CTR_OBLFOP          0
# CTR_OBLTFP          0
# CTR_OBLDCO          0
# CTR_OBLTVA          0
# CTR_OFODEC         10
# CTR_OFODEP         10
# CTR_OFODET         10
# CTR_OBLAUT         10
# CTR_OBLASS         10
# CTR_ODTIMB         10
# CTR_OBLTCL          0
# CTR_OBLTHO         10
# CTR_OBLDLI         10
# CTR_OBLTVI         10
# CTR_RATISS          0
# EXE_EXERCI          0
# TVA_CHAFF6       1974
# TVA_CHAFF7       1974
# TVA_CHAF10       1974
# TVA_CHAF12       1974
# TVA_CAF125       1974
#                 ...
# SND_MNTPRD_E    23610
# SND_MNTTVA_E    23610
# SND_MNTDRC_E    23610
# SND_MNTAVA_E    23610
# SND_MNTTAX_E    23610
# SND_MNTPAY_E    23610
# SND_MNTAIR_E    23610
# SND_MNTPRD_A    21631
# SND_MNTTVA_A    21631
# SND_MNTDRC_A    21631
# ...

# %%
total_cells = np.product(train.shape)
total_missing = missing_values_count.sum()

(total_missing/total_cells) * 100
# Out:
# 26.623525069002476

# %%
train.drop(['SND_MNTPRD_E','SND_MNTTVA_E','SND_MNTDRC_E','SND_MNTAVA_E','SND_MNTTAX_E','SND_MNTPAY_E','SND_MNTAIR_E','SND_MNTPRD_A','SND_MNTTVA_A','SND_MNTDRC_A','SND_MNTAVA_A','SND_MNTTAX_A','SND_MNTPAY_A','SND_MNTAIR_A'],axis=1,inplace=True)

# %%
missing_values_count
# Out:
# BCT_CODBUR          0
# CTR_MATFIS          0
# CTR_CATEGO_X        0
# FJU_CODFJU          0
# CTR_CESSAT          0
# ACT_CODACT          0
# CTR_OBLDIR          0
# CTR_OBLACP          0
# CTR_OBLRES          0
# CTR_OBLFOP          0
# CTR_OBLTFP          0
# CTR_OBLDCO          0
# CTR_OBLTVA          0
# CTR_OFODEC         10
# CTR_OFODEP         10
# CTR_OFODET         10
# CTR_OBLAUT         10
# CTR_OBLASS         10
# CTR_ODTIMB         10
# CTR_OBLTCL          0
# CTR_OBLTHO         10
# CTR_OBLDLI         10
# CTR_OBLTVI         10
# CTR_RATISS          0
# EXE_EXERCI          0
# TVA_CHAFF6       1974
# TVA_CHAFF7       1974
# TVA_CHAF10       1974
# TVA_CHAF12       1974
# TVA_CAF125       1974
#                 ...
# SND_MNTPRD_E    23610
# SND_MNTTVA_E    23610
# SND_MNTDRC_E    23610
# SND_MNTAVA_E    23610
# SND_MNTTAX_E    23610
# SND_MNTPAY_E    23610
# SND_MNTAIR_E    23610
# SND_MNTPRD_A    21631
# SND_MNTTVA_A    21631
# SND_MNTDRC_A    21631
# ...

# %%
train.drop(['SND_MNTPRD_I','SND_MNTTVA_I','SND_MNTDRC_I','SND_MNTAVA_I','SND_MNTTAX_I','SND_MNTPAY_I','SND_MNTAIR_I'],inplace=True,axis=1)

# %%
#train.drop(['ADB_MNTORD''FAC_MNTPRI_F','FAC_MFODEC_F','FAC_MNTDCO_F','FAC_MNTTVA_F','FAC_MNTPRI_C','FAC_MFODEC_C','FAC_MNTDCO_C','FAC_MNTTVA_C'],inplace=True,axis=1)

# %%
from statistics import mean

send_data=train[['ADB_MNTORD','FAC_MNTPRI_F','FAC_MFODEC_F','FAC_MNTDCO_F','FAC_MNTTVA_F','FAC_MNTPRI_C','FAC_MFODEC_C','FAC_MNTDCO_C','FAC_MNTTVA_C']]

mean_df = round(send_data.mean())

train[['ADB_MNTORD','FAC_MNTPRI_F','FAC_MFODEC_F','FAC_MNTDCO_F','FAC_MNTTVA_F','FAC_MNTPRI_C','FAC_MFODEC_C','FAC_MNTDCO_C','FAC_MNTTVA_C']]=train[['ADB_MNTORD','FAC_MNTPRI_F','FAC_MFODEC_F','FAC_MNTDCO_F','FAC_MNTTVA_F','FAC_MNTPRI_C','FAC_MFODEC_C','FAC_MNTDCO_C','FAC_MNTTVA_C']].fillna(mean_df)

#mean_df = round(send_data.mean())

#print("Filling with mean value of {}".format(send_data))

#train = train.fillna(mean_df)

#train.head()

# %%
train.head()
# Out:
#    BCT_CODBUR  CTR_MATFIS CTR_CATEGO_X  FJU_CODFJU  CTR_CESSAT  ACT_CODACT  \
# 0          49       14185            P          99           1        6101
# 1         221        6032            P          99           0        6271
# 2         181        8907            P          99           0        6102
# 3         252        5783            M          22           0        4403
# 4         234        1477            P          99           0        6312
#
#    CTR_OBLDIR  CTR_OBLACP  CTR_OBLRES  CTR_OBLFOP  ...     target  \
# 0           4           2           2           2  ...  13.575957
# 1           8           2           1           1  ...  11.692894
# 2           4           2           2           2  ...   0.000000
# 3           4           2           2           2  ...  16.237871
# 4           8           2           2           1  ...  13.399983
#
#    FAC_MNTPRI_F  FAC_MFODEC_F  FAC_MNTDCO_F  FAC_MNTTVA_F  FAC_MNTPRI_C  \
# ...

# %%
sns.heatmap(train.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
sendy_data=train.isnull().sum().sort_values(ascending = False).head(30)
sendy_data
# Out:
# AX5_MNTMAR    6043
# AX1_BRTIMP    6043
# AX2_HONORA    6043
# AX2_LOYERS    6043
# AX3_REVCAP    6043
# TVA_BASEQL    1974
# TVA_BASEQI    1974
# TVA_DEDEQI    1974
# TVA_BASAUL    1974
# TVA_DEDAUL    1974
# TVA_BASAUI    1974
# TVA_DEDRSM    1974
# TVA_DEDAUI    1974
# TVA_BASRSM    1974
# TVA_RSNRES    1974
# TVA_TRSPOR    1974
# TVA_DEDREG    1974
# TVA_RESTIT    1974
# TVA_MNTPAY    1974
# TVA_MOIFIN    1974
# TVA_CRDFIN    1974
# TVA_DEDEQL    1974
# TVA_CRDINI    1974
# TVA_DEDIMB    1974
# TVA_BASIMB    1974
# TVA_ACHNDD    1974
# TVA_MOIDEB    1974
# TVA_TOTDUE    1974
# TVA_CHAF36    1974
# TVA_CHAF29    1974
# dtype: int64

# %%
# replace all NA's the value that comes directly after it in the same column, 
# then replace all the reamining na's with 0
#filled_train=train.fillna(method = 'ffill', axis=0).fillna(0)
import statistics as stats

#print(train.mode

#mean_df = round(train.mode())
#print("Filling with mean value of {}".format(filled_train))
#filled_train = train.fillna(mean_df)
filled_train=train.fillna(method = 'bfill', axis=1).fillna(0)

# %%
plt.figure(figsize = (15,10))
sns.heatmap(filled_train.corr())

# %%
sns.heatmap(filled_train.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
test.isnull().sum()
# Out:
# BCT_CODBUR          0
# CTR_MATFIS          0
# CTR_CATEGO_X        0
# FJU_CODFJU          0
# CTR_CESSAT          0
# ACT_CODACT          0
# CTR_OBLDIR          0
# CTR_OBLACP          0
# CTR_OBLRES          0
# CTR_OBLFOP          0
# CTR_OBLTFP          0
# CTR_OBLDCO          0
# CTR_OBLTVA          0
# CTR_OFODEC          4
# CTR_OFODEP          4
# CTR_OFODET          4
# CTR_OBLAUT          4
# CTR_OBLASS          4
# CTR_ODTIMB          4
# CTR_OBLTCL          0
# CTR_OBLTHO          4
# CTR_OBLDLI          4
# CTR_OBLTVI          4
# CTR_RATISS          0
# EXE_EXERCI          0
# TVA_CHAFF6        808
# TVA_CHAFF7        808
# TVA_CHAF10        808
# TVA_CHAF12        808
# TVA_CAF125        808
#                 ...
# SND_MNTAIR_I     8859
# SND_MNTPRD_E    10120
# SND_MNTTVA_E    10120
# SND_MNTDRC_E    10120
# SND_MNTAVA_E    10120
# SND_MNTTAX_E    10120
# SND_MNTPAY_E    10120
# SND_MNTAIR_E    10120
# SND_MNTPRD_A     9300
# SND_MNTTVA_A     9300
# ...

# %%
test.drop(['SND_MNTPRD_E','SND_MNTTVA_E','SND_MNTDRC_E','SND_MNTAVA_E','SND_MNTTAX_E','SND_MNTPAY_E','SND_MNTAIR_E','SND_MNTPRD_A','SND_MNTTVA_A','SND_MNTDRC_A','SND_MNTAVA_A','SND_MNTTAX_A','SND_MNTPAY_A','SND_MNTAIR_A'],axis=1,inplace=True)

# %%
test.drop(['SND_MNTPRD_I','SND_MNTTVA_I','SND_MNTDRC_I','SND_MNTAVA_I','SND_MNTTAX_I','SND_MNTPAY_I','SND_MNTAIR_I'],inplace=True,axis=1)

# %%
#test.drop(['ADB_MNTORD'],inplace=True,axis=1)
from statistics import mean

send_data=test[['ADB_MNTORD','FAC_MNTPRI_F','FAC_MFODEC_F','FAC_MNTDCO_F','FAC_MNTTVA_F','FAC_MNTPRI_C','FAC_MFODEC_C','FAC_MNTDCO_C','FAC_MNTTVA_C']]

mean_df = round(send_data.mean())

test[['ADB_MNTORD','FAC_MNTPRI_F','FAC_MFODEC_F','FAC_MNTDCO_F','FAC_MNTTVA_F','FAC_MNTPRI_C','FAC_MFODEC_C','FAC_MNTDCO_C','FAC_MNTTVA_C']]=train[['ADB_MNTORD','FAC_MNTPRI_F','FAC_MFODEC_F','FAC_MNTDCO_F','FAC_MNTTVA_F','FAC_MNTPRI_C','FAC_MFODEC_C','FAC_MNTDCO_C','FAC_MNTTVA_C']].fillna(mean_df)

# %%
sns.heatmap(test.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
test.isnull().sum().sort_values(ascending = False).head(30)
# Out:
# AX3_REVCAP    2627
# AX2_LOYERS    2627
# AX1_BRTIMP    2627
# AX2_HONORA    2627
# AX5_MNTMAR    2627
# TVA_BASEQI     808
# TVA_DEDEQI     808
# TVA_BASAUL     808
# TVA_DEDAUL     808
# TVA_BASAUI     808
# TVA_DEDAUI     808
# TVA_DEDRSM     808
# TVA_BASEQL     808
# TVA_BASRSM     808
# TVA_RSNRES     808
# TVA_TRSPOR     808
# TVA_DEDREG     808
# TVA_RESTIT     808
# TVA_MNTPAY     808
# TVA_MOIFIN     808
# TVA_ACHSUS     808
# TVA_DEDEQL     808
# TVA_CRDINI     808
# TVA_DEDIMB     808
# TVA_BASIMB     808
# TVA_ACHNDD     808
# TVA_MOIDEB     808
# TVA_TOTDUE     808
# TVA_CHAF36     808
# TVA_CHAF29     808
# dtype: int64

# %%
filled_test=test.fillna(method = 'bfill', axis=1).fillna(0)


#mean_df2 = round(test.mean())
#print("Filling with mean value of {}".format(mean_df2))
#filled_test = test.fillna(mean_df2)

# %%
sns.heatmap(filled_test.isnull(), yticklabels=False, cbar=False, cmap='viridis')

# %%
pd.get_dummies(filled_train['CTR_CATEGO_X'], drop_first=True).shape
# Out:
# (25053, 3)

# %%
cCTR_CATEGO_X1 = pd.get_dummies(filled_train['CTR_CATEGO_X'], drop_first=True)
cCTR_CATEGO_X2= pd.get_dummies(filled_test['CTR_CATEGO_X'], drop_first=True)

# %%
filled_test.drop(['CTR_CATEGO_X'], axis= 1, inplace=True)

filled_train.drop(['CTR_CATEGO_X'], axis= 1, inplace=True)

# %%
filled_train = pd.concat([filled_train,cCTR_CATEGO_X1], axis=1)
filled_test = pd.concat([filled_test,cCTR_CATEGO_X2], axis=1)

# %%
filled_train.drop(['N'], axis= 1, inplace=True)

# %%
filled_train.head()
# Out:
#    BCT_CODBUR  CTR_MATFIS  FJU_CODFJU  CTR_CESSAT  ACT_CODACT  CTR_OBLDIR  \
# 0          49       14185          99           1        6101           4
# 1         221        6032          99           0        6271           8
# 2         181        8907          99           0        6102           4
# 3         252        5783          22           0        4403           4
# 4         234        1477          99           0        6312           8
#
#    CTR_OBLACP  CTR_OBLRES  CTR_OBLFOP  CTR_OBLTFP  ...  FAC_MFODEC_F  \
# 0           2           2           2           2  ...     6003678.0
# 1           2           1           1           1  ...     6003678.0
# 2           2           2           2           2  ...     6003678.0
# 3           2           2           2           2  ...     6003678.0
# 4           2           2           1           1  ...     6003678.0
#
#    FAC_MNTDCO_F  FAC_MNTTVA_F  FAC_MNTPRI_C  FAC_MFODEC_C  FAC_MNTDCO_C  \
# ...

# %%
filled_test.head()
# Out:
#    BCT_CODBUR  CTR_MATFIS  FJU_CODFJU  CTR_CESSAT  ACT_CODACT  CTR_OBLDIR  \
# 0           9       11802          99           0        6306           8
# 1         255        2713          99           0        4409           4
# 2         201         152          22           0        3603           4
# 3         302        7698          22           0        4203           4
# 4         152         544          99           0        6307           4
#
#    CTR_OBLACP  CTR_OBLRES  CTR_OBLFOP  CTR_OBLTFP  ...  FAC_MFODEC_F  \
# 0           2           2           2           2  ...     6003678.0
# 1           2           2           2           2  ...     6003678.0
# 2           2           2           2           2  ...     6003678.0
# 3           2           2           2           2  ...     6003678.0
# 4           2           2           2           2  ...     6003678.0
#
#    FAC_MNTDCO_F  FAC_MNTTVA_F  FAC_MNTPRI_C  FAC_MFODEC_C  FAC_MNTDCO_C  \
# ...

# %%
X_train = filled_train.drop(['target','id'], axis=1)
y_train = filled_train['target']
X_test = filled_test.drop(['id'], axis=1)



X_train.shape, y_train.shape, X_test.shape

#from sklearn.preprocessing import Normalizer

#X = filled_train.drop(['target','id']
#y = df.iloc[:, -1:]normal = Normalizer().fit_transform(X)
# Out:
# ((25053, 99), (25053,), (10738, 99))

# %%
#from sklearn.model_selection import train_test_split

#X_train, X_test, y_train, y_test = train_test_split(filled_train.drop(['target','id'],axis=1),filled_train['target'],test_size=0.30,random_state=101)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()

lm.fit(X_train,y_train)

predictions = lm.predict(X_test)


accuracy1=lm.score(X_train, y_train)


#accuracy=lm.score(X_test, y_test)

print(accuracy1)

#from sklearn import metrics

#print('MAE:', metrics.mean_absolute_error(y_test, predictions))
#print('MSE:', metrics.mean_squared_error(y_test, predictions))
#print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# 0.06091567107778895

# %%
#from sklearn.neighbors import KNeighborsRegressor

from sklearn.ensemble import GradientBoostingRegressor

gb_clf = GradientBoostingRegressor(n_estimators=10000, max_features=2, max_depth=4, random_state=0,learning_rate=0.01)
gb_clf.fit(X_train, y_train)


predictions=gb_clf.predict(X_test)
predictions = predictions


accuracy1=gb_clf.score(X_train, y_train)

#accuracy=gb_clf.score(X_test, y_test)

print(accuracy1)


#from sklearn import metrics

#print('MAE:', metrics.mean_absolute_error(y_test, predictions))
#print('MSE:', metrics.mean_squared_error(y_test, predictions))
#print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# 0.41547594748422323

# %%
#from sklearn.ensemble import RandomForestRegressor

#tree = RandomForestRegressor(n_estimators=1000, random_state=0,max_depth=4).fit(X_train, y_train)
#print("Training set score: {:.2f}".format(tree.score(X_train, y_train)))
#print("Test set score: {:.2f}".format(tree.score(X_test, y_test)))


#from sklearn import metrics

#print('MAE:', metrics.mean_absolute_error(y_test, predictions))
#print('MSE:', metrics.mean_squared_error(y_test, predictions))
#print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

# %%
# The coefficients-print('Coefficients: \n', gb_clf.coef_)

# %%
predictions = np.array(predictions, dtype=np.int8)
predictions
# Out:
# array([14, 14, 14, ..., 13,  7,  6], dtype=int8)

# %%
#from sklearn.metrics import classification_report,confusion_matrix

# %%
#from sklearn.metrics import classification_report
#print(classification_report(y_test,predictions))

# %%
submission = pd.DataFrame({
    'id': filled_test['id'],
    'target': predictions
})

submission.to_csv('Good_submission3.csv', index = False)
submission.head()
# Out:
#          id  target
# 0  test_id0      14
# 1  test_id1      14
# 2  test_id2      14
# 3  test_id3      12
# 4  test_id4      14
